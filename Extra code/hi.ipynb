# %%
// Import the functions you need from the SDKs you need
import { initializeApp } from "firebase/app";
import { getAnalytics } from "firebase/analytics";
// TODO: Add SDKs for Firebase products that you want to use
// https://firebase.google.com/docs/web/setup#available-libraries

// Your web app's Firebase configuration
// For Firebase JS SDK v7.20.0 and later, measurementId is optional
const firebaseConfig = {
  apiKey: "AIzaSyARE2_6sPeRDwXmmxfWKFkqJujwZquV8yM",
  authDomain: "projet-x-2fdb7.firebaseapp.com",
  projectId: "projet-x-2fdb7",
  storageBucket: "projet-x-2fdb7.firebasestorage.app",
  messagingSenderId: "763602766404",
  appId: "1:763602766404:web:5428d69f0998399b9b4a11",
  measurementId: "G-P9LPZZK9D2"
};

// Initialize Firebase
const app = initializeApp(firebaseConfig);
const analytics = getAnalytics(app);

# %%
rules_version = '2';

service cloud.firestore {
  match /databases/{database}/documents {
    match /{document=**} {
      allow read, write: if false;
    }
  }
}
note:

# %%
import dropbox

# Your generated access token
ACCESS_TOKEN = "sl.u.AGIr4oz-74g4VUSiir7nNyUEbS10SleWQwPkySTVeuszNudaFkQ0hObchckcLm7X7wqbl0NYLVnsEHtt_talKaaLZn1GKNJxvQ_EeBggoLIYuO0bN7JOCwAsvZtWAJQQ2hqdyTiLVNaOox9xZI7XZwIH8OMhDgatDVWEa8pgMoftZtvm88DOSpwh91AYkwWAlUODcK33AhLj6eo3woyQEFsoFz6sH0BStEdmpDbJrKIPcX55l0edV1nQJlipSI4Tn3rAefKxZ6iHQ2qhbKa31XhZbxYRY6lk9Q77bRAKDwOaudEA1iSapdy12vF-pWP6pEsCttTQkWioGBHC-qAZ8Q1Z3WzCdb278VpARN9VBra9-eYXcZ6NUyREgckI9uu3RjvvwwndkuLCXlpEKkIlDKhvKj4QT6VvrWRke0xE16OiMiUh_KIch0ucin50UPdEQraabSMFVH3aHswI66RMwgEfVCpw2vpXQMNVgBjvHtDAL9JC5iLrtoQimbHT1S-dtkTRF0v7t1EpfaAlvUo9-_tzR5u3O2UFPAvIMBuGtJ42HI9BNU5BnNSLq_hkaFN8yKcxPwUHjNZi80ebcmnFHZS3AMVdZHqCe5phxy_O4u9J6lUHHcSM9Dy3ULYBZVakjmRsS10hUIuNvWfQm6KQx91RMfbG4ppDO6LvVlSRsVoEIMOhC4emdI9QCbmo13SWeBJrsUgwGisI0iDMulAduRnxc2qgOuxC9t43zlGqyDXvIJIptqu2Iu2cdc2XtlXFxby7Sd0RcK3meQtjW8vUX-LiXEqhc7E3AipqoG7hej4ayLaAl-cGqOYJDIqhcjLd_1LIJuxpjip9pjEc0h_jeylblZeYTRR9H0xbDCsERQPkDzrrmpxueRk7qN48UieGxlv2TCcsnfYehJFS3d0f-Aj85NroL8f5wDf4W7SMlU38k4xdkQwO2dwJFPeMAs83kvOJ3SFz1E7Ey_eyHPbg-zEkn63ndfp8DIXGb940Hc71KbUDvyuoxf5LR3ogsrTOn6aE-BzYf6-c4GE2VNU4btnyxO4nCp5C806nsP2VzE6J90hbwQUaCvBxyBDywgwGtW7PcQgLsmZwfkQu9LLPtOBpehIa1JwwXfxqGBuuKsqqcUumpiLuOz3RwsVzVjkAbpaA5v4fRTfDSuXDKX6X39QtplyJzAbX-aKQaDnnW9axDoCJUqPfJbI3UOK0aIUmESRIJKEv2earDKy0J_bmoDcom7O2Df3UNPw_aOAcu9Oo_HguhW0N6QZP0KSGtauRdTv4J0Om4_RBZ6iMYGSmuI1s"

dbx = dropbox.Dropbox(ACCESS_TOKEN)

def upload_file(local_path, dropbox_path):
    """Upload a file to Dropbox"""
    with open(local_path, "rb") as f:
        dbx.files_upload(f.read(), dropbox_path, mode=dropbox.files.WriteMode.overwrite)
    shared_link_metadata = dbx.sharing_create_shared_link_with_settings(dropbox_path)
    return shared_link_metadata.url

# %%
import dropbox

# Your Dropbox token
ACCESS_TOKEN = "sl.u.AGKb0KxD2t0exzGAAqYou9qwpzgoQqhUjQWfPJu845FqrBCPyXWJZwcOgG1L-tn8vxT19OhmWSHUvZm-4wvIk2-nt3GIHEua41E8jLdeeMk-oW_p4NuG5t238s67xjFOzJPMNYBmVjG8IHeEZNFawr5g_HYVAfgA6P-gFQfbWWofeEo1brwpwAKFPQ1u9axtKdswTVJx-bB3Gn6V9PVW79xO10fJCXp64o2_UZzUjmRzLy-5Zz68aIp0m5WJorpC25Jt9NZpeKNbdnSeSF9YDCCeH-xGXz_RCvJgCV_jK-jwtT0F9GsbtQE38qkaAM4CaBTVBj7hmzazmfFk34iMW2PPc8V94_HzFJbTHbnuoe4bCCp_IdHwxo4AMZASfdxBnji0vauesmKqf8h50SQwRLxAl8JXgZAULmM_93gzcF990GhG0Odmynf98pyjLClBsU5Q4rR_b7S79KK9LVrghNKGZJEKW-1LmDsyBCunA2WH0sxF_EyZnluKetKGuoGDYj5OY3YVcj10fglY7JCPfOUTLGLuE-H_ZSIMPwUJyacHBTxvUchN660Z9SmHdgTJCiJfZTUNzqXMR-0Pq1JkRtZcXvfWyoKQx7PYi2D1BYQ_9l7q0goj-DxKM-ghU1MpiJjtafQ-145yx27LxguQ16v8MZMHAJPT1xiVe8B7_Wdp64_gNTVeGnCIuf-rmwME80HnP19wdCSMQMK0G3I8DDToB-FV-6c6IB_6dKnTlp5H27j7yKuO7sg7MGtKpj27Xaf4gxBFAuUFGAY8s6_deBkyAHSUrJN25nmH8NyL5255-vBr-iL_WwJIdLovekc4l9_I7ubfZH8zASVbP7qCQejHwcrL6wU2cLgRCmXsecztIvTrtyzK9SPpF7cUB8Ymq0p8u7IB5YBxl16_kOpUNRU5OsLR33WJXBdfyCQWqt_33iSo1kjXi-LHKL_WvY_aiPXPtkJ2rRh8N-5VaCnvym-L7I6GpiuHjdZOcPw9UPhCPfxCHb75nfIdhvtVGy9q1nf-93qvivv99TslZxcjT7DXtHPyAJNydURase4bSUJlkWsygrO28z9Dbxks2TXy_f91GPLcvQAw4UhUdF1ZyVsoPfCM-iv39fO2eiex9Bu5IaA50aNOO3hjr4CIDSmPaPXoEXqPuI6BTI36aV3eBS2lLKWjgz65428usJGIb6P3sNG4SLRKQRNZVYzBOtLcDZuzH7duuBm73J4DZ0sEEOacrHxV7lVr2xHZBqG4ocgueW1FHTU1kuO3x6NxmmFfWx1brTXkWLJm1BZ9djTGVBd4"

dbx = dropbox.Dropbox(ACCESS_TOKEN)

def download_file(dropbox_path, local_path):
    try:
        metadata, res = dbx.files_download(dropbox_path)
        with open(local_path, "wb") as f:
            f.write(res.content)
        print("Downloaded:", local_path)
    except Exception as e:
        print("Error:", e)

# Example usage
dropbox_path = "/uploads/rB26gN0oDOapFtvw4rm7aHQVCHX2/dfacc330-8ece-4d87-b606-aeef185fd5b0_word_test.docx"
local_path = "test_download.docx"

download_file(dropbox_path, local_path)
# Out:
# Downloaded: test_download.docx

# %%
import sys
import os

# 🔥 Set the path to your Flask app root folder
PROJECT_PATH = "/Users/michaelmakhoul/Desktop/ProjectX/app"
sys.path.append(PROJECT_PATH)

import firebase_admin
from firebase_admin import credentials, firestore

# 🔥 Absolute path to your service account key
SERVICE_ACCOUNT_PATH = "/Users/michaelmakhoul/Desktop/ProjectX/serviceAccountKey.json"

# Initialize Firebase app if not already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate(SERVICE_ACCOUNT_PATH)
    firebase_admin.initialize_app(cred)

# Firestore client
db = firestore.client()

# 🔥 Put the UID you want to test here
TEST_UID = "rB26gN0oDOapFtvw4rm7aHQVCHX2"

def test_fetch_user_files():
    print(f"Fetching files for UID: {TEST_UID}\n")

    uploads_ref = db.collection("uploads")
    query = uploads_ref.where("user_id", "==", TEST_UID)
    docs = list(query.stream())

    if not docs:
        print("No documents found for this UID")
        return

    print(f"Found {len(docs)} documents:\n")
    for doc in docs:
        data = doc.to_dict()
        print("DOCUMENT ID:", doc.id)
        print("Filename:", data.get("filename"))
        print("Dropbox Path:", data.get("dropbox_path"))
        print("URL:", data.get("url"))
        print("Uploaded At:", data.get("uploaded_at"))
        print("-----------------------------------")

if __name__ == "__main__":
    test_fetch_user_files()
# Out:
# Fetching files for UID: rB26gN0oDOapFtvw4rm7aHQVCHX2
#
# Found 4 documents:
#
# DOCUMENT ID: WUpBKzxh3w0HA8n7puRa
# Filename: CASE.docx
# Dropbox Path: /uploads/rB26gN0oDOapFtvw4rm7aHQVCHX2/7deb2645-8821-4d52-bde2-94aca484d46f_CASE.docx
# URL: https://www.dropbox.com/scl/fi/qc288dgwpmcaptnlhcw12/7deb2645-8821-4d52-bde2-94aca484d46f_CASE.docx?rlkey=83dnva0xtevu0dfeh6d6uhwk5&dl=0
# Uploaded At: 2025-12-07 22:00:39.450000+00:00
# -----------------------------------
# DOCUMENT ID: Yv6ljUPJ6qtcn2CRM3hu
# Filename: CASE.docx
# Dropbox Path: /uploads/rB26gN0oDOapFtvw4rm7aHQVCHX2/4d6e4b75-7efb-4330-be7c-29c431bcf358_CASE.docx
# URL: https://www.dropbox.com/scl/fi/ok39jzgwmbrjytb06ja3x/4d6e4b75-7efb-4330-be7c-29c431bcf358_CASE.docx?rlkey=eo18jb63i78tbqzfu9cn44caq&dl=0
# Uploaded At: 2025-12-07 21:38:44.467000+00:00
# -----------------------------------
# DOCUMENT ID: bSCdRB2p385jrq9iZ1Sr
# Filename: CASE.docx
# ...
